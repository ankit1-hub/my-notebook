# %%
print(2+3)
print(2**2)
# Out:
# 5
# 4

# %%
a = 2+3*4
b = (2+3)*4
print(a)
print(b)
# Out:
# 14
# 20

# %%
print(0.1+0.2)
print(0.1+0.9)
#Ignore the extra values of output just enjoys.
# Out:
# 0.30000000000000004
# 1.0

# %%
print(4/2)
#When you divide any two numbers, even if they are integers the output will be float
# Out:
# 2.0

# %%
print(1+2.0)
print(3.0+2)
print(3.0**2)
#if you mix an integer and a float in any other operation , you will get a float as well
# Out:
# 3.0
# 5.0
# 9.0

# %%
#If the number is too large we can group it using underscores.
universal_age = 12_000_000_000
print(universal_age)
#This features works for integer and float
# Out:
# 12000000000

# %%
#Multiple assignment
x,y,z = 1,2,3
print(x+y)
print(x+z)
# Out:
# 3
# 4

# %% [markdown]
# sometimes we have to declare some constant values like pi, exponential,etc.
# such type of constants should be declare using capital letters.e.g, pI = 3.1516

# %%
radius = 12
PI = 3.1516 #constant thats why declare with capital letters
area = PI*radius**2
print(area)
# Out:
# 453.83040000000005

# %% [markdown]
# 1)Do addition,subtraction,multiplication and division?

# %%
print(3+5)
print(11-3)
print(64/8)
print(4*2)
# Out:
# 8
# 8
# 8.0
# 8

# %%
favourite_number = 12
message = f"your favourite number is {favourite_number}"
print(message)
# Out:
# your favourite number is 12

# %% [markdown]
# Anything followed by the hash(#) mark in your code is ignored by the python intrepreter.
# previously you have seen many lines that are followed by hash(#) in this tutorial that shows notes.
# And that lines are called comments

# %%
#This is comment

# %%
length = 2
breadth = 3
perimeter = 2 * (length + breadth)
print(perimeter)
#This program gives the perimeter of the room whose length is 2m and breadth is 3m.
# Out:
# 10

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
