# %% [markdown]
# **Introduction_of_variable**

# %%
message = "hello python world!"
print(message)
message1 ="hello python crash course world"
print(message1)
# Out:
# hello python world!
# hello python crash course world

# %% [markdown]
# **rules for naming variable**

# %% [markdown]
# variable name must start with underscore or alphabet. Remember that " never with number"

# %%
_name = "hero"                           #variable name started with underscore 
work = "actor"                           #variable name start with alphabet 
print(_name)
print(work)
#1_message = " welcome to the day one "  #variable name started with number 
#print(message_1)
    #output,  syntax_error:invalid decimal literal
# Out:
# hero
# actor

# %% [markdown]
# space is not allowded while writing variables

# %%
#an kit  = 1
#print(an kit)
    #SyntaxError: invalid syntax

# %% [markdown]
# Avoid using python keywords and functions as variable names

# %%
#print = 1
#print(print)
   #TypeError: 'int' object is not callable

# %% [markdown]
# variable name should be short and descriptive

# %%
student_name ="ankit"
print(student_name)
# Out:
# ankit

# %% [markdown]
# Be careful using upercase letter O and lowercase letter l with 0 and 1

# %%
mesage = " hello python crash course reader!"
print(mesage)
# Out:
#  hello python crash course reader!

# %% [markdown]
# 1) Assign a message to a variable , and then print that message

# %%
message = "intrested in learning"
print(message)
# Out:
# intrested in learning

# %% [markdown]
# 2) Assign a message to a variable, And print that message.then change the value of the variable to a new message,
# and print the new message.

# %%
message = "intrested in learning python"
print(message)
new_mess
# Out:
# intrested in learning python
